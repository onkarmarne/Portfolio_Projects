# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\lenovo\Desktop\DA_FreeCodeCamp\Customer Call List.xlsx')

# %%
df = df.drop_duplicates ()

# %%
#df['Last_Name'] = df['Last_Name'].str.lstrip('...')
#df['Last_Name'] = df['Last_Name'].str.lstrip('/')
#df['Last_Name'] = df['Last_Name'].str.rstrip('_')

#ABOVE 3 STATEMENTS AND THE STATEMENT BELOW WORK THE SAME.

#df['Last_Name'] = df['Last_Name'].str.strip("123._/")  #FASTEST WAY TO FILTER LAST NAME COLUMN

# %%
#df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]','',regex = True)   #This will filter the phone numbers i.e. removes '-','/','|'
#df['Phone_Number'] = df['Phone_Number'].apply(lambda x: str(x)) #This will treat the data in column as string 
#df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10]) #This will add '-' before the indexes mentioned 

# MAKE SURE YOU RUN THE BELOW 2 STATEMENTS AFTER COMMENTING ABOVE STATEMENTS BECAUSE IF YOU DON'T , IT WILL WORK ACCORDINGLY AND INSERT '-'AT MENTIONED 
# INDEXES CAUSING THE OUTPUT AS '-' IN PLACE OF nan & Na IN PHONE NUMBER COLUMN.

#df['Phone_Number'] = df['Phone_Number'].replace('nan--','')
#df['Phone_Number'] = df['Phone_Number'].replace('Na--','')

# %%
#df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',', expand = True)  

#THIS WILL SEPERATE THE ADDRESS ON THE BASIS OF ','

# %%
df['Paying Customer'] = df['Paying Customer'].str.replace('Yes','Y')
df['Paying Customer'] = df['Paying Customer'].str.replace('No','N')

#Changing the values in Paying Customer Column from Yes to Y and No to N

# %%
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('Yes','Y')
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('No','N')

#Changing the values in Do_Not_Contact Column from Yes to Y and No to N

# %%
df = df.fillna('')  #It will fill empty space wherever there is something missing

# %%
for x in df.index:
    if df.loc[x,"Do_Not_Contact"] == 'Y':
        df.drop(x, inplace = True)

# %%
for x in df.index:
    if df.loc[x,"Phone_Number"] == '':
        df.drop(x, inplace = True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 4         1005        Jon        Snow  876-678-3469
# 7         1008   Sherlock      Holmes  876-678-3469
# 9         1010      Peter      Parker  123-545-5421
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 4                 123 Dragons Road               Y              N
# 7                    98 Clue Drive               N              N
# 9       25th Main Street, New York               Y              N
# ...

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number  \
# 0        1001      Frodo     Baggins  123-545-5421
# 1        1005        Jon        Snow  876-678-3469
# 2        1008   Sherlock      Holmes  876-678-3469
# 3        1010      Peter      Parker  123-545-5421
# 4        1013        Don      Draper  123-543-2345
# 5        1014     Leslie       Knope  876-678-3469
# 6        1015       Toby  Flenderson  304-762-2467
# 7        1016        Ron     Weasley  123-545-5421
# 8        1017   Michael        Scott  123-643-9775
# 9        1020     Anakin   Skywalker  876-678-3469
#
#                           Address Paying Customer Do_Not_Contact  \
# 0           123 Shire Lane, Shire               Y              N
# 1                123 Dragons Road               Y              N
# 2                   98 Clue Drive               N              N
# 3      25th Main Street, New York               Y              N
# 4                2039 Main Street               Y              N
# ...
